# %%
# !pip install streamlit
# Out:
# WARNING: Ignoring invalid distribution -pype1 (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# streamlit 라이브러리는 빠르고 쉽게 웹앱을 만들기 위한 라이브러리입니다.
#
# 설치시 이메일을 입력하는 부분이 출력되면 사용하는 이메일을 입력합니다.
#
# 업데이트 내용 등을 이메일을 통해 알려줍니다.
#
# 다음의 streamlit의 사이트 주소로 개발현황, 사용법 등을 알 수 있습니다.
#
# https://streamlit.io/

# %% [markdown]
# !pip install pyupbit
#
# 업비트에서 가상화페 데이터를 조회 가능한 라이브러리입니다.
