# %% [markdown]
# # 판다스로 값 읽고 그래프로 그리기

# %%
#데이터 값을 읽어오기 위해 pandas 임포트
import pandas as pd

#파일의 경로 지정
file_path = r'C:\Users\user\로또번호 시각화하기\lotto.xlsx'

#openpyxl을 엔진으로 사용하여 pandas의 데이터프레임으로 엑셀 파일을 불러옵니다.
df_from_excel = pd.read_excel(file_path,engine='openpyxl')

#데이터프레임의 0번,1번 인덱스를 삭제합니다.
df_from_excel = df_from_excel.drop(index=[0,1])

#columns의 이름 재정의
df_from_excel.columns =[
    '년도','회차','추첨일','1등당첨자수','1등당첨금액',
    '2등당첨자수','2등당첨금액','3등당첨자수','3등당첨금액',
    '4등당첨자수','4등당첨금액','5등당첨자수','5등당첨금액',
    '당첨번호1','당첨번호2','당첨번호3','당첨번호4',
    '당첨번호5','당첨번호6','보너스번호'
]

#데이터프레임의 상위 5개 데이터 출력
print(df_from_excel.head())

#데이터프레임의 회차 열의 값들을 출력
print(df_from_excel['회차'].values)

#데이터프레임의 1등당첨금액 열의 값들을 출력
print(df_from_excel['1등당첨금액'].values)
# Out:
#      년도    회차         추첨일 1등당첨자수          1등당첨금액 2등당첨자수       2등당첨금액 3등당첨자수  \
# 2  2022  1039  2022.10.29     16  1,585,019,672원     80  52,833,990원   2773
# 3   NaN  1038  2022.10.22     15  1,627,457,225원     77  52,839,521원   3364
# 4   NaN  1037  2022.10.15     15  1,708,576,825원     78  54,762,078원   2713
# 5   NaN  1036  2022.10.08      9  2,837,323,167원     64  66,499,762원   2593
# 6   NaN  1035  2022.10.01      8  3,231,193,735원     71  60,679,695원   2848
#
#        3등당첨금액  4등당첨자수   4등당첨금액   5등당첨자수  5등당첨금액 당첨번호1  당첨번호2  당첨번호3  당첨번호4  \
# 2  1,524,241원  140403  50,000원  2359126  5,000원     2    3.0    6.0   19.0
# 3  1,209,466원  154690  50,000원  2436512  5,000원     7   16.0   24.0   27.0
# 4  1,574,435원  137021  50,000원  2279500  5,000원     2   14.0   15.0   22.0
# 5  1,641,337원  133443  50,000원  2231388  5,000원     2    5.0   22.0   32.0
# 6  1,512,732원  141624  50,000원  2366499  5,000원     9   14.0   34.0   35.0
#
#    당첨번호5  당첨번호6 보너스번호
# 2   36.0   39.0    26
# 3   37.0   44.0     2
# 4   27.0   33.0    31
# 5   34.0   45.0    39
# 6   41.0   42.0     2
# [1039 1038 1037 ... 3 2 1]
# ['1,585,019,672원' '1,627,457,225원' '1,708,576,825원' ... '2,000,000,000원'
#  '2,002,006,800원' '0원']
